# %%
#importando as bibliotecas
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use("seaborn")

# %%
#upload de arquivo
from google.colab import files
arq = files.upload()
# Out:
#      <input type="file" id="files-ecb6dba8-0fab-4bf4-9fb1-05ccb7c97a78" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ecb6dba8-0fab-4bf4-9fb1-05ccb7c97a78">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving AdventureWorks.xlsx to AdventureWorks.xlsx

# %%
#criando o dataframe
df = pd.read_excel("AdventureWorks.xlsx")

# %%
#visualizando as 5 primeiras linhas
df.head()
# Out:
#   Data Venda Data Envio  ID Loja  ...            Marca   Classe  Cor
# 0 2008-05-09 2008-05-29      199  ...  Adventure Works  Regular  Red
# 1 2008-05-12 2008-05-17      306  ...  Adventure Works  Regular  Red
# 2 2008-05-14 2008-05-20      306  ...  Adventure Works  Regular  Red
# 3 2008-05-21 2008-05-27      306  ...  Adventure Works  Regular  Red
# 4 2008-06-20 2008-06-27      306  ...  Adventure Works  Regular  Red
#
# [5 rows x 16 columns]

# %%
#quantida de linhas e colunas
df.shape
# Out:
# (904, 16)

# %%
#tipos de dados
df.dtypes
# Out:
# Data Venda        datetime64[ns]
# Data Envio        datetime64[ns]
# ID Loja                    int64
# ID Produto                 int64
# ID Cliente                 int64
# No. Venda                 object
# Custo Unitário           float64
# Preço Unitário           float64
# Quantidade                 int64
# Valor Desconto           float64
# Valor Venda              float64
# Produto                   object
# Fabricante                object
# Marca                     object
# Classe                    object
# Cor                       object
# dtype: object

# %%
#Receita total
df["Valor Venda"].sum()
# Out:
# 5984606.1426

# %%
#Qual o custo total
df["Custo"] = df["Custo Unitário"].mul(df["Quantidade"]) # criando a culula Custo

# %%
df.head(3)
# Out:
#   Data Venda Data Envio  ID Loja  ...   Classe  Cor    Custo
# 0 2008-05-09 2008-05-29      199  ...  Regular  Red  2091.48
# 1 2008-05-12 2008-05-17      306  ...  Regular  Red  2091.48
# 2 2008-05-14 2008-05-20      306  ...  Regular  Red  2091.48
#
# [3 rows x 17 columns]

# %%
#Qual o custo total
round(df["Custo"].sum(), 2)
# Out:
# 2486783.05

# %%
#Temos o custo , receita e o total, acharemos o lucro total agora
#vamos criar uma coluna de lucro que sera Receita - Custo
df["Lucro"] = df["Valor Venda"] - df["Custo"]

# %%
df.head(1)
# Out:
#   Data Venda Data Envio  ID Loja  ID Produto  ...   Classe  Cor    Custo    Lucro
# 0 2008-05-09 2008-05-29      199         384  ...  Regular  Red  2091.48  2456.52
#
# [1 rows x 18 columns]

# %%
#Qual o total do lucro
round(df["Lucro"].sum(), 2)
# Out:
# 3497823.09

# %%
#Criando uma coluna com o total de dias para enviar o produto
df["Tempo_Envio"] = df["Data Envio"] - df["Data Venda"]

# %%
df.head(1)
# Out:
#   Data Venda Data Envio  ID Loja  ID Produto  ...  Cor    Custo    Lucro  Tempo_Envio
# 0 2008-05-09 2008-05-29      199         384  ...  Red  2091.48  2456.52      20 days
#
# [1 rows x 19 columns]

# %% [markdown]
# ##Agora precisamos saber a media de tempo de envio para cada marca, para isso precisamos da coluna Tempo_Envio como numerica

# %%
#extraindo apenas os dias
df["Tempo_Envio"] = (df["Data Envio"] - df["Data Venda"]).dt.days

# %%
df.head(1)
# Out:
#   Data Venda Data Envio  ID Loja  ...    Custo    Lucro Tempo_Envio
# 0 2008-05-09 2008-05-29      199  ...  2091.48  2456.52          20
#
# [1 rows x 19 columns]

# %%
#veriricando o tipo da coluna tempo_envio
df["Tempo_Envio"].dtype
# Out:
# dtype('int64')

# %%
#media de tempo de envio por marca
df.groupby("Marca")["Tempo_Envio"].mean()
# Out:
# Marca
# Adventure Works    8.663866
# Contoso            8.470930
# Fabrikam           8.510121
# Name: Tempo_Envio, dtype: float64

# %% [markdown]
# ##missing values

# %%
#verificando se temos dados faltantes
df.isnull().sum()
# Out:
# Data Venda        0
# Data Envio        0
# ID Loja           0
# ID Produto        0
# ID Cliente        0
# No. Venda         0
# Custo Unitário    0
# Preço Unitário    0
# Quantidade        0
# Valor Desconto    0
# Valor Venda       0
# Produto           0
# Fabricante        0
# Marca             0
# Classe            0
# Cor               0
# Custo             0
# Lucro             0
# Tempo_Envio       0
# dtype: int64

# %% [markdown]
# ##Como saber o lucro por ano e por marca

# %%
#vamos agrupar por ano e marca
df.groupby([df["Data Venda"].dt.year, "Marca"])["Lucro"].sum()
# Out:
# Data Venda  Marca
# 2008        Adventure Works             306,641.16
#             Contoso                      56,416.00
#             Fabrikam                  1,557,020.55
# 2009        Adventure Works             405,395.08
#             Contoso                     138,258.95
#             Fabrikam                  1,034,091.35
# Name: Lucro, dtype: float64

# %%
pd.options.display.float_format = '{:20,.2f}'.format

# %%
#resetando o index
lucro_ano = df.groupby([df["Data Venda"].dt.year, "Marca"])["Lucro"].sum().reset_index()
lucro_ano
# Out:
#    Data Venda            Marca                Lucro
# 0        2008  Adventure Works           306,641.16
# 1        2008          Contoso            56,416.00
# 2        2008         Fabrikam         1,557,020.55
# 3        2009  Adventure Works           405,395.08
# 4        2009          Contoso           138,258.95
# 5        2009         Fabrikam         1,034,091.35

# %%
#qual o total de produtos vendidos
df.groupby("Produto")["Quantidade"].sum().sort_values(ascending=False)
# Out:
# Produto
# Headphone Adapter for Contoso Phone E130 Silver    25232
# Headphone Adapter for Contoso Phone E130 White     25008
# Adventure Works Laptop15.4W M1548 Black             1089
# Fabrikam Trendsetter 2/3'' 17mm X100 Grey           1087
# Adventure Works Laptop15.4W M1548 Red               1047
# Fabrikam Trendsetter 2/3'' 17mm X100 Black           926
# Fabrikam Trendsetter 1/3'' 8.5mm X200 Black          884
# Fabrikam Trendsetter 1/3'' 8.5mm X200 Grey           845
# Fabrikam Trendsetter 1/3'' 8.5mm X200 White          789
# Name: Quantidade, dtype: int64

# %%
#grafico total de produtos vendidos
df.groupby("Produto")["Quantidade"].sum().sort_values(ascending=True).plot.barh(title="Total Produtos Vendidos")
plt.xlabel("Ano")
plt.ylabel("Receita")
# Out:
# Text(0, 0.5, 'Receita')

# %%
df.groupby(df["Data Venda"].dt.year)["Lucro"].sum().sort_values(ascending=True).plot.bar(title="Lucro x Ano")
plt.xlabel("Ano")
plt.ylabel("Receita")
# Out:
# Text(0, 0.5, 'Receita')

# %%
df.groupby(df["Data Venda"].dt.year)["Lucro"].sum()
# Out:
# Data Venda
# 2008           1,920,077.71
# 2009           1,577,745.38
# Name: Lucro, dtype: float64

# %%
#selecionando as vendas de 2009
df_2009 = df[df["Data Venda"].dt.year == 2008]

# %%
df_2009.head()
# Out:
#   Data Venda Data Envio  ...                Lucro  Tempo_Envio
# 0 2008-05-09 2008-05-29  ...             2,456.52           20
# 1 2008-05-12 2008-05-17  ...             2,456.52            5
# 2 2008-05-14 2008-05-20  ...             2,456.52            6
# 3 2008-05-21 2008-05-27  ...             2,456.52            6
# 4 2008-06-20 2008-06-27  ...             2,456.52            7
#
# [5 rows x 19 columns]

# %%
df.groupby(df_2009["Data Venda"].dt.month)["Lucro"].sum().plot(title="Lucro x Mes")
plt.xlabel("Mes")
plt.ylabel("Lucro")
# Out:
# Text(0, 0.5, 'Lucro')

# %%
df_2009.groupby("Marca")["Lucro"].sum().plot.bar(title="Lucro x Marca")
plt.xlabel("Marca")
plt.ylabel("Lucro")
plt.xticks(rotation="horizontal")
# Out:
# (array([0, 1, 2]), <a list of 3 Text major ticklabel objects>)

# %%
df_2009.groupby("Classe")["Lucro"].sum().plot.bar(title="Lucro x Classe")
plt.xlabel("Classe")
plt.ylabel("Lucro")
plt.xticks(rotation="horizontal")
# Out:
# (array([0, 1]), <a list of 2 Text major ticklabel objects>)

# %%
df["Tempo_Envio"].describe()
# Out:
# count                 904.00
# mean                    8.54
# std                     3.06
# min                     4.00
# 25%                     6.00
# 50%                     9.00
# 75%                    11.00
# max                    20.00
# Name: Tempo_Envio, dtype: float64

# %%
#grafico bloxplot
plt.boxplot(df["Tempo_Envio"])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7fac76b09750>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fac76b35710>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7fac76b334d0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7fac76b331d0>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7fac76b23810>,
#   <matplotlib.lines.Line2D at 0x7fac76b35bd0>]}

# %%
#histograma
plt.hist(df["Tempo_Envio"])
# Out:
# (array([217., 137.,  70., 179., 115., 185.,   0.,   0.,   0.,   1.]),
#  array([ 4. ,  5.6,  7.2,  8.8, 10.4, 12. , 13.6, 15.2, 16.8, 18.4, 20. ]),
#  <a list of 10 Patch objects>)

# %%
#tempo minimo de envio
df["Tempo_Envio"].min()
# Out:
# 4

# %%
#tempo maximo de envio
df["Tempo_Envio"].max()
# Out:
# 20

# %%
#identificando o outlier
df[df["Tempo_Envio"] == 20]
# Out:
#   Data Venda Data Envio  ...                Lucro  Tempo_Envio
# 0 2008-05-09 2008-05-29  ...             2,456.52           20
#
# [1 rows x 19 columns]

# %%
df.to_csv("df_vendas_novo.csv", index=False)
