# %%
#importando as bibliotecas
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
plt.style.use("seaborn")

# %%
#criando o dataframe
df = pd.read_csv("data/kc_house_data.csv")

# %%
#verificando as 5 primeiras linas do dataframe
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0       3.0       1.00         1180
# 1  6414100192  20141209T000000  538000.0       3.0       2.25         2570
# 2  5631500400  20150225T000000  180000.0       2.0       1.00          770
# 3  2487200875  20141209T000000  604000.0       4.0       3.00         1960
# 4  1954400510  20150218T000000  510000.0       3.0       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
#quantida de linhas e colunas
df.shape
# Out:
# (21613, 21)

# %%
#tipos de dados
df.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms         float64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
#verificando se temos dados faltantes
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           1
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
#verificando quais sao os dados faltantes
filtro = df.floors.isnull()
df.loc[filtro]
# Out:
#             id             date     price  bedrooms  bathrooms  sqft_living  \
# 11  9212900260  20140527T000000  468000.0       2.0        1.0         1160
#
#     sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 11      6000     NaN           0     0  ...      7         860            300
#
#     yr_built  yr_renovated  zipcode    lat     long  sqft_living15  sqft_lot15
# 11      1942             0    98115  47.69 -122.292           1330        6000
#
# [1 rows x 21 columns]

# %%
#verificando quais sao os dados faltantes
filtro = df.bedrooms.isnull()
df.loc[filtro]
# Out:
#             id             date     price  bedrooms  bathrooms  sqft_living  \
# 46  8945200830  20150325T000000  210490.0       NaN       1.00          990
# 57  2799800710  20150407T000000  301000.0       NaN       2.50         2420
# 67  3717000160  20141009T000000  287000.0       NaN       2.50         2240
# 88  1332700270  20140519T000000  215000.0       NaN       2.25         1610
#
#     sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 46      8528     1.0           0     0  ...      6         990              0
# 57      4750     2.0           0     0  ...      8        2420              0
# 67      4648     2.0           0     0  ...      7        2240              0
# 88      2040     2.0           0     0  ...      7        1610              0
#
#     yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 46      1966             0    98023  47.3066 -122.371           1228
# ...

# %%
mean = df["bedrooms"].mean()
df["bedrooms"].fillna(mean, inplace=True)

# %%
mean = df["floors"].mean()
df["floors"].fillna(mean, inplace=True)

# %%
#verificando se temos dados faltantes
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
#descrevendo os dados
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370910      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.929998      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494332      0.007542      0.234303      3.409430
# ...

# %%
#histograma dos quartos e banheiros
df[['bedrooms','bathrooms']].hist(bins=30,alpha=0.5,color='Green')
# Out:
# <img src="data:image/png;base64,..." width="640">
# array([[<AxesSubplot:title={'center':'bedrooms'}>,
#         <AxesSubplot:title={'center':'bathrooms'}>]], dtype=object)

# %%
#media dos quartos
df["bedrooms"].mean()
# Out:
# 3.3709102688694528

# %%
#valor max dos quartos

# %%
df["bedrooms"].max()
# Out:
# 33.0

# %%
#valor min dos quartos

# %%
df["bedrooms"].min()
# Out:
# 0.0

# %%
#desvio padrao
df["bedrooms"].std()
# Out:
# 0.9299983928421763

# %%
df["bedrooms"].describecribe()
# Out:
# count    21613.000000
# mean         3.370910
# std          0.929998
# min          0.000000
# 25%          3.000000
# 50%          3.000000
# 75%          4.000000
# max         33.000000
# Name: bedrooms, dtype: float64

# %%
# %matplotlib notebook
matplotlib.style.use('ggplot')
df.boxplot(column='bedrooms')
# Out:
# <img src="data:image/png;base64,..." width="800">
# <AxesSubplot:>
